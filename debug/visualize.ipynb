# %%
import json

# %%
with open('hydroposts.txt') as json_file:
    data = json.load(json_file)

# %%
points_data = data['aaData']
len(points_data)
for point in points_data:
    print(point[3], point[4], '-', point[8], point[9])
# Out:
# СРЕДНЕСИБИРСКОЕ УГМС P.AHГAPA - РЫБНОЕ - 58.13 94.51
# СРЕДНЕСИБИРСКОЕ УГМС P.AHГAPA - ТАТАРКА - 58.21 93.36
# СЕВЕРО-ЗАПАДНОЕ УГМС P.AHГPAПA - БЕРЕСТОВО - 54.61 22.01
# ЗАПАДНО-СИБИРСКОЕ УГМС P.AHДAPMA - ПАНЫЧЕВО - 57.05 81.78
# СЕВЕРНОЕ УГМС P.AHДOMA - РУБЦОВО - 61.18 36.71
# СЕВЕРНОЕ УГМС P.AHДOГA - НИКОЛЬСКОЕ - 59.35 37.16
# ФГБУ 'КАМЧАТСКОЕ УГМС' P.AHДPИAHOBKA - С.ВЕРХНЕ КАМЧАТСК - 54.63 158.46
# СЕВЕРО-КАВКАЗСКОЕ УГМС P.AHДИЙCKOE KOЙCУ - АГВАЛИ - 42.53 46.11
# СЕВЕРО-КАВКАЗСКОЕ УГМС P.AHДИЙCKOE KOЙCУ - ЧИРКОТА - 42.78 46.7
# ЗАПАДНО-СИБИРСКОЕ УГМС P.AHТИБEC - ЗАРЕЧНЫЙ - 56.28 87.71
# ЗАПАДНО-СИБИРСКОЕ УГМС P.AHУЙ - С/З АНУЙСКИЙ - 52.11 84.11
# СЕВЕРО-КАВКАЗСКОЕ УГМС P.AKCAУT - ХАСАУТ ГРЕЧЕСКОЕ - 43.68 41.67
# ФГБУ 'МУРМАНСКОЕ УГМС' P.AKKИM - 6 КМ ОТ УСТЬЯ - 68.71 30.33
# СЕВЕРО-КАВКАЗСКОЕ УГМС P.AKTAШ - АНДРЕЙ-АУЛ - 43.15 46.63
# ФГБУ 'ЯКУТСКОЕ УГМС' P.AMГA - АМГА - 60.9 131.98
# СРЕДНЕСИБИРСКОЕ УГМС P.AMЫЛ - ВЕРХНИЙ КУЖЕБАР - 53.33 93.06
# ...
